# %%
import os
import pickle
import tensorflow as tf
from mido import MidiFile
from keras.models import Sequential
from keras.layers import Dense
import numpy
from keras.utils import to_categorical
import statistics 
from statistics import mode
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
files = []
songs = {}
genres = {}

# %%
def gettingFiles(files_dir):
    for r, d, f in os.walk(files_dir):
        for file in f:
            if '.mid' in file:
                files.append(os.path.join(r, file))


def getNoteRange():
    for file in files:
        vector = []
        mid = MidiFile(file)
        for i, track in enumerate(mid.tracks):
            for msg in track:
                if hasattr(msg, 'note'):
                    if msg.velocity != 0:
                        vector.append(msg.note)
        # print(vector)
        name = file[file.find("\\") + 1:]
        print(name)
        songs[name] = vector
    print(len(songs))

def getGenre():
    file = open("../MIDI_Genres/trainLabels.txt", "r");
    for line in file:
        index = line.find(",")
        name = line[0 : index]
        genre = line[index + 1 : index + 2]
        genres[name] = genre
        print(name + " : " + genre)

def avg(song):
    return sum(song) / len(song)

def common(song):
    return max(set(song), key = song.count)

def distance(song):
    return [song[i + 1] - song[i] for i in range(len(song) - 1)]

def histogram(song):
    songArray = np.array(song);
    hist, edges = np.histogram(songArray, np.arange(1, 121))
    return hist.tolist()

# %%
gettingFiles('../MIDI_Genres/MIDI_Genres/train_set')
getNoteRange()
getGenre()
# Out:
# 020-sati.mid
# 20th_century_fox.mid
# 435question.mid
# 57_1a_(c)bachovich.mid
# 73_3_(c)bachovich.mid
# 7thst.mid
# 87-15b.mid
# 99_ways_to_die.mid
# a real mother for ya.mid
# A-D-D.mid
# ab-astor_tango.mid
# ab-cumparsita_tango.mid
# ab-johnny_b_goode.mid
# ab-tutti_fruitti.mid
# aces_high.mid
# ACKER-GS.mid
# ac_chantons.mid
# Aenima.mid
# against.mid
# ahahohno.mid
# aida1_celeste.mid
# aida2fin.mid
# AJobin-GirlIpanema.mid
# AlbertKing-BornUnderBadSign.mid
# aleigha.mid
# AliceCooper_Elected.mid
# alive.mid
# allepsaa.mid
# AllmanBrothers-BlueSky.mid
# AllmanBrothers-InMemoryOfElizabethReedUnplugged.mid
# AllmanBrothers-StatesBoroughBlues.mid
# AllmanBrothers-WhippingPost.mid
# allw_cp3.mid
# All_The_Small_Things.mid
# amorcomoelnuestro.mid
# Amor_vittorioso.mid
# angelaonmymind.mid
# angelus.mid
# animal.mid
# another.mid
# another_brick_in_the_wall.mid
# anyplace.mid
# anytime.mid
# aqua-barbie_girl.mid
# around.mid
# around_the_world.mid
# Astor-tango.mid
# astor_tango.mid
# atIknew.mid
# atthehop.mid
# At_Last.mid
# AT_THE_CLUB.mid
# av002a1.mid
# av_molti2.mid
# A_Cold_Day_In_Hell.mid
# b00038.mid
# b00160.mid
# b00178.mid
# b00181.mid
# b00186.mid
# b00188.mid
# b00192.mid
# b00219.mid
# b00245.mid
# b00263.mid
# b00287.mid
# b0028_6.mid
# b00300.mid
# b00317.mid
# b0424.mid
# bach531.mid
# bach7.mid
# bad_love.mid
# BAILSAL.mid
# barber02_unavoce.mid
# barneys.mid
# bartok_sonata3.mid
# bastien04_befraget.mid
# Beat_On_The_Brat.mid
# Beautiful_People.mid
# Becoming.mid
# beet4.mid
# beet5.mid
# beforeac.mid
# belfiore.mid
# BEN_E_KING_DON_T_PLAY_THAT_SONG__YOU_LIED_.mid
# BEN_E_KING_STAND_BY_ME.mid
# Berlioz16.mid
# berlioz_symfan_5.mid
# Be_With_You_enrique_iglesias.mid
# BigMess.mid
# BIG_BOSS.mid
# billiejn.mid
# birdland.mid
# bjc17_2b.mid
# blazers.mid
# Blitzkrieg_Bop.mid
# Blowin' Smoke.mid
# bluemon.mid
# BLUES.mid
# BluesBrothers-EverybodyNeedsSomebody.mid
# bluesy.mid
# blues_brothers-sweet_home.mid
# BobbyBlueBland_ATouchOfBlues.mid
# bolivar.mid
# BOOKER_T___THE_MGs_HIP_HUGGER.mid
# BOOKER_T___THE_MGs_TIME_IS_TIGHT.mid
# Boom_Boom_Boom.mid
# BORGAN_Lues.mid
# Bound_For_The_Floor.mid
# boyp.mid
# boys_are_back.mid
# Brahms-Rhapsody in G.mid
# Break_On_Through_Doors.mid
# breezin.mid
# Brick house.mid
# britney_spears_oops_i_did_it_again.mid
# britney_spears_stronger.mid
# BRUJERIA.mid
# BuddyGuy-MaryHadALitltleLamb.mid
# bux_cfug.mid
# cant help falling in love.mid
# can_t_turn_you_loose.mid
# cap07.mid
# carly_simon_nobody_does_it_better.mid
# CARNAVAL.mid
# cc_rider.mid
# celebrate.mid
# celine_dion_all_by_myself.mid
# chameleon.mid
# chanlace.mid
# chega.mid
# chestnuts.mid
# chicken.mid
# Chicken_Shack.mid
# chillout.mid
# chop4.mid
# chop8.mid
# cibux183.mid
# Cissy Strut.mid
# cjam.mid
# clapton-layla.mid
# CleanSweep.mid
# cm_altri_canti_damor.mid
# cm_combattimento1.mid
# codding_town.mid
# coisalin.mid
# Cold_Shot.mid
# College_Full.mid
# comeback.mid
# comehome.mid
# comerain.mid
# concerto_1_(c)izumi.mid
# concerto_flute_314-2.mid
# control.mid
# copmw.mid
# Corcovad.mid
# cosi15_non.mid
# Count_On_The_Blues.mid
# Cowboys_From_Hell.mid
# crazy_reg.mid
# Cream_StrangeBrew.mid
# Crossfire.mid
# Crossroads_Blues.mid
# cumparsita_tango.mid
# cut the cake.mid
# czaldy.mid
# d-100purelove.mid
# d-123trainwithme.mid
# d-allthatshewants.mid
# d-anothernight.mid
# d-anything.mid
# d-automaticlover.mid
# d-badboy.mid
# d-beautifullife.mid
# d-becauseimlovingyou.mid
# d-bemylover.mid
# d-celebratethelove.mid
# d-children.mid
# d-closetoyou.mid
# d-cocojamboo.mid
# d-cometakemyhand.mid
# d-dancingwithanangel.mid
# DANCE.mid
# dancing.mid
# DATDoor.mid
# day_fool.mid
# dc-choochoochaboogie.mid
# deadend.mid
# deb3.mid
# deb5.mid
# december.mid
# dedi.mid
# Desafinado78.mid
# despavv.mid
# despdpc.mid
# despeie.mid
# despmpl.mid
# dgaria22.mid
# doc-whos_been_talkin.mid
# dock_of_the_bay_2.mid
# Doin_Time.mid
# dongio04_madamina.mid
# Dose.mid
# Down.mid
# downalley.mid
# Dragula.mid
# dream.mid
# dreams.mid
# Drugs_Are_Good.mid
# ductia.mid
# dufaycas.mid
# Dust_My_Broom.mid
# dvorak_symphony_9_1l.mid
# dwb-ltsally.mid
# earlyam.mid
# egblues.mid
# elvis_presley_all_shook_up.mid
# eraraute.mid
# EricClapton-SunshineOfYourLove.mid
# estamp02.mid
# estamp4.mid
# etude.mid
# falando.mid
# felicid.mid
# filthy.mid
# firebird.mid
# fivemil1.mid
# Flagpole_Sitta.mid
# foxbabe.mid
# FreddieKing-HelpMeThroughTheDay.mid
# FreddieKing-SanHoZaySenSaSun.mid
# freedom.mid
# fun3.mid
# funct_u.mid
# g-goyf.mid
# gamespeopleplay.mid
# GaryMoore-StillGotTheBlues.mid
# gboffire.mid
# gbp_serpina.mid
# gel.mid
# GentleRain.mid
# Get_Off_My_Back.mid
# gfh_se_bramate_damar.mid
# gfh_va_tacito.mid
# gianni2_omio.mid
# gimmesh.mid
# gimme_all_your_lovin.mid
# gonions.mid
# GoodMorningLittleSchoolGirl.mid
# go_again.mid
# go_the_distance.mid
# greenday_jaded.mid
# Guerilla_Radio.mid
# hallfima.mid
# hand3.mid
# hand6.mid
# hangin.mid
# Happy_Guy.mid
# Heart_Shaped_Box.mid
# heaven.mid
# heaven_is.mid
# helpme.mid
# hen4sanc.mid
# here i am baby.mid
# heyjoe.mid
# Hey_Bartender.mid
# Higher.mid
# hindemithrag.mid
# hit_the_lights.mid
# Hobophobic.mid
# holding.mid
# homeinsa.mid
# hootieblues.mid
# Hot pants.mid
# house.mid
# HowIns.mid
# how_am_i_supposwithout_you.mid
# How_Blue_Can_You_Get.mid
# hp_amin.mid
# hp_when_i_am.mid
# hysteria.mid
# i'll_never_break_your_heart.mid
# i'm_broken.mid
# icumen.mid
# idv_die_weiber.mid
# in2deep.mid
# India.mid
# Iron_Man.mid
# irresponsible_hate_anthem.mid
# it's your thing.mid
# it's_all_comingk_to_me_now.mid
# itapoan.mid
# I_NEVER_LOVED_A_MAN__THE_WAY_I_LOVE_YOU.mid
# JACKIE_WILSON_BABY_WORKOUT.mid
# jahlive.mid
# jailhouse.mid
# james_brown-i_feel_good.mid
# james_brown-papas_got.mid
# JAMES_BROWN_COLD_SWEAT.mid
# JAMES_BROWN_I_GOT_THE_FEELIN_.mid
# Jazzy_Bossa_Nova_Baby.mid
# jbgood_r.mid
# JEFFERSON_AIRPLANE__White_Rabbit.mid
# jesus_freak.mid
# jeurobin.mid
# JimmieCox-NobodyKnowsWhenYouAreDownAndOut.mid
# JimmieYancey-StateStreetSpecial.mid
# jns_bene.mid
# JohnLeeHooker-Dimples.mid
# joy_bossa_nova.mid
# Juke.mid
# Just Blues.mid
# k030.mid
# k058.mid
# kalenda.mid
# kc-band.mid
# Keep_It_To_Yourself.mid
# Killing_In_The_Name_Of.mid
# Knowledge.mid
# Know_Your_Enemy.mid
# kravitz-are_you_gonna_go_my_way.mid
# L2003_01.mid
# L2003_03.mid
# L2003_08.mid
# lapin.mid
# Last Night The DJ Saved My Life.mid
# lazy.mid
# la_rotta.mid
# LA_SALSA.mid
# ldsummer.mid
# LedZeppelin-SinceIveBeenLovingYouBaby.mid
# light_my_fire.mid
# liszt5.mid
# liszt7.mid
# lithium.mid
# Little_Red_Rooster.mid
# LITTLE_RICHARD__Slippin_and_Slidin.mid
# LLUVIA.mid
# lndnchip.mid
# lndnpart.mid
# lndnques.mid
# lohengrin06_fernem.mid
# looking.mid
# lope-isl.mid
# louis_armstrong-all_the_time_in_the_world.mid
# lowdown.mid
# Mable.mid
# machbont.mid
# machdous.mid
# machmaag.mid
# madunn.mid
# makeit.mid
# Mambo_(Mambo_Mix).mid
# Mamoita.mid
# maputo.mid
# marley-sherrif.mid
# master_blaster.mid
# may be tomorrow.mid
# meistersinger11_prize.mid
# Mendelssohn-AMidsummer-Overture.mid
# Mendelssohn-ViolinConcerto64-Alegro.mid
# merulo2.mid
# Midnight_Train.mid
# mistymountainhop.mid
# moanin.mid
# MOJO.mid
# momagot.mid
# Morena.mid
# Mouvement_1.mid
# MuddyWaters-HoochieCoochieMan.mid
# mvoyage.mid
# myfavgame.mid
# my_destiny.mid
# my_girl.mid
# m_people-moving_on_up.mid
# naturalmystic.mid
# nevrknow.mid
# Nitefunk.mid
# NOESTAS.mid
# nofx-don't_call_me_white.mid
# notgoodenough.mid
# nothingsgonnachangemylove-georgebenson.mid
# nowthat.mid
# No_Particular_Place.mid
# nra-she's_driving.mid
# ock4up.mid
# ombra.mid
# omniscur.mid
# OneBourbonOneScotchOneBeer.mid
# onenote.mid
# OpFunk.mid
# oppatt.mid
# orpheus.mid
# paradise_city.mid
# Paranoid.mid
# Periodico.mid
# photograph.mid
# piano_concerto_449_1.mid
# piano_sonata_330_1_(c)oguri.mid
# piano_sonata_570_1_(c)oguri.mid
# play that funky music.mid
# plush.mid
# por_una.mid
# ppanther_37.mid
# Private_Emotion.mid
# prokofievSymph52.mid
# propagandhi-anti-manifesto.mid
# ps-lucille.mid
# PUENTE.mid
# purple_haze.mid
# quartet_20_6_1_(c)simonetto.mid
# quartet_33_3_2_(c)simonetto.mid
# quartet_33_6_2_(c)simonetto.mid
# r1t.mid
# raylight.mid
# rebel.mid
# redf_glr.mid
# redwine.mid
# REGGAE.mid
# reggaecouldyoubeloved.mid
# ReggaeisthisLove.mid
# Reggaejammin.mid
# rememberourgoodtimes.mid
# respect.mid
# revelations.mid
# riders.mid
# rightnow.mid
# roadhouse_blues.mid
# RockMeBaby.mid
# rolloverbeethoven.mid
# romino.mid
# rootcult.mid
# roses_are_red.mid
# Ruby_Soho.mid
# RufusThomas-WalkingTheDog.mid
# runaway.mid
# salsa.mid
# Salsa_(Gilberto_SantaRosa)_(Amor_mio_no_te_vayas).mid
# Salsa_(Gilberto_SantaRosa)_(Dime_Cuando).mid
# Salsa_(La_Negra_Tomasa).mid
# salsa_salsa.mid
# saltare2.mid
# santana-blackmagicwoman.mid
# schlsout.mid
# schoenberg_6stucke2.mid
# school.mid
# schoskk6.mid
# screeching_weasel-dirty_needles.mid
# sexy MF.mid
# shesnot.mid
# shoes.mid
# SHOT_GUN.mid
# Silly_Thing.mid
# Sing_we_and_chant_it.mid
# sinquere.mid
# siunavez.mid
# sjostakovitsj_melancholie.mid
# Smells_Like_Teen_Spirit.mid
# smoke.mid
# smooth.mid
# Sodanco.mid
# somehap.mid
# sonata_17_(c)izumi.mid
# sonata_19_1_(c)iscenko.mid
# sonata_4_2_(c)iscenko.mid
# SonnyBoyWilliamsonII-DontStartMeToTalking.mid
# SonnyBWilliamson-YourFuberalMyTrial.mid
# SonnyBWilliamsonII-UnSeenEye.mid
# southern.mid
# spice.mid
# stairway_to_heaven.mid
# start.mid
# Stockhausen_StarSigns.mid
# suddenly.mid
# Suite_1.mid
# sunflower.mid
# surfin.mid
# sweat01.mid
# Sweet_16.mid
# Sweet_Little_Sixteen.mid
# symphony_088_2_(c)edwards.mid
# symphony_092_1_(c)edwards.mid
# symphony_183_2_(c)ishii.mid
# symphony_35_385_3_(c)cvikl.mid
# symphony_41_551_3_(c)cvikl.mid
# takriver.mid
# tallnom2.mid
# tangoaa1.mid
# TangoArg.mid
# tangoen_wb.mid
# tango_alaluzde.mid
# tango_alousie.mid
# tango_boedo.mid
# tango_celos.mid
# tango_chique.mid
# tango_cumparsa.mid
# tango_elchoclo.mid
# tango_lapunial.mid
# tango_t-uno.mid
# tango_tangoarg.mid
# tav_nom.mid
# TBoneWalker-CallItStormyMonday.mid
# TECHNO.mid
# teddybea.mid
# teen_idols-ketchup_soup.mid
# temple_of_the_bull.mid
# thank you for letting me be mice elf.mid
# The On-Line Boogie.mid
# these_arms_of_mine.mid
# THE_BLUES_BROTHERS_FLIP_FLOP_BLUES.mid
# THE_BLUES_BROTHERS_MINNIE_THE_MOOCHER.mid
# THE_BLUES_BROTHERS_SHAKE_A_TAILFEATHER_BABY.mid
# THE_COMMITMENTS_MIDNIGHT_HOUR.mid
# THE_COMMITMENTS_TRY_A_LITTLE_TENDERNESS.mid
# The_Distance.mid
# the_four_horsemen.mid
# the_shortest_straw.mid
# THE_STAPLE_SINGERS_RESPECT_YOURSELF.mid
# The_Thrill_Is_Gone.mid
# think.mid
# think_twice.mid
# three_times_a_lady.mid
# through_the_never.mid
# tomorrowpeople.mid
# trio66_1.mid
# Triste.mid
# trouble.mid
# truecols.mid
# TUMQUEMA.mid
# TuNoLeAmas.mid
# turnlove.mid
# unbreak.mid
# u_smile.mid
# van_halen-jump.mid
# vdreq21a.mid
# victomagnum.mid
# victoquartiagnus2.mid
# victpang.mid
# villagepeople_machoman.mid
# vision.mid
# wagn4.mid
# waitinginvain.mid
# Walk.mid
# waterloo.mid
# watrmeln.mid
# Wave3.mid
# wavem.mid
# wb_ye_sacred_muses.mid
# Webern_Aufblick.mid
# webern_op28b.mid
# webern_sym1_cmc.mid
# wedding.mid
# whatlove.mid
# where_the_river_flows.mid
# white_room.mid
# whitney_didntwealmosthaveitall.mid
# Whitney_houston_i_will_always_love_you.mid
# whosgirl.mid
# whothink.mid
# WILSON_PICKET_MEDLEY.mid
# wmyself2.mid
# wrong-Bartok_all3.mid
# x_ol_lucia.mid
# x_ol_matona_mia_cara.mid
# x_ol_un_jeune_moine.mid
# YMCA.mid
# you_give_love_a_bad_name.mid
# yursong.mid
# zimbabwe.mid
# zz_top-tush.mid
# 571
# 020-sati.mid : 5
# 20th_century_fox.mid : 6
# 435question.mid : 7
# 57_1a_(c)bachovich.mid : 7
# 73_3_(c)bachovich.mid : 7
# 7thst.mid : 5
# 87-15b.mid : 7
# 99_ways_to_die.mid : 6
# A-D-D.mid : 6
# ACKER-GS.mid : 3
# AJobin-GirlIpanema.mid : 9
# ASK4IT2.MID : 6
# AT_THE_CLUB.mid : 5
# AWALK.MID : 6
# A_Cold_Day_In_Hell.mid : 5
# Aenima.mid : 6
# AlbertCollins_AGoodFoolIsHardToFind.mid : 5
# AlbertKing-BornUnderBadSign.mid : 6
# AliceCooper_Elected.mid : 6
# All_The_Small_Things.mid : 6
# AllmanBrothers-BlueSky.mid : 6
# AllmanBrothers-InMemoryOfElizabethReedUnplugged.mid : 6
# AllmanBrothers-StatesBoroughBlues.mid : 6
# AllmanBrothers-WhippingPost.mid : 6
# Amor_vittorioso.mid : 7
# Astor-tango.mid : 9
# At_Last.mid : 5
# BAILSAL.mid : 9
# BEN_E_KING_DON_T_PLAY_THAT_SONG__YOU_LIED_.mid : 5
# BEN_E_KING_STAND_BY_ME.mid : 5
# BIG_BOSS.mid : 5
# BLACK.MID : 6
# BLKHOLE.MID : 6
# BLUES.mid : 5
# BOOKER_T___THE_MGs_HIP_HUGGER.mid : 5
# BOOKER_T___THE_MGs_TIME_IS_TIGHT.mid : 5
# BORGAN_Lues.mid : 5
# BRUJERIA.mid : 9
# Be_With_You_enrique_iglesias.mid : 3
# Beat_On_The_Brat.mid : 6
# Beautiful_People.mid : 6
# Becoming.mid : 6
# Berlioz16.mid : 7
# BigMess.mid : 5
# Blitzkrieg_Bop.mid : 6
# Blowin' Smoke.mid : 5
# BluesBrothers-EverybodyNeedsSomebody.mid : 5
# BobbyBlueBland_ATouchOfBlues.mid : 5
# Boom_Boom_Boom.mid : 5
# Bound_For_The_Floor.mid : 6
# Brahms-Rhapsody in G.mid : 7
# Break_On_Through_Doors.mid : 6
# Brick house.mid : 5
# BuddyGuy-MaryHadALitltleLamb.mid : 6
# CARNAVAL.mid : 9
# Chicken_Shack.mid : 5
# Cissy Strut.mid : 5
# CleanSweep.mid : 3
# Cold_Shot.mid : 6
# College_Full.mid : 6
# Corcovad.mid : 9
# Count_On_The_Blues.mid : 5
# Cowboys_From_Hell.mid : 6
# Cream_StrangeBrew.mid : 6
# Crossfire.mid : 6
# Crossroads_Blues.mid : 6
# DANCE.mid : 3
# DATDoor.mid : 6
# Desafinado78.mid : 9
# Doin_Time.mid : 6
# Dose.mid : 6
# Down.mid : 6
# Dragula.mid : 6
# Drugs_Are_Good.mid : 6
# Dust_My_Broom.mid : 5
# EricClapton-SunshineOfYourLove.mid : 6
# FALLLOVE.MID : 6
# Flagpole_Sitta.mid : 6
# FreddieKing-HelpMeThroughTheDay.mid : 5
# FreddieKing-SanHoZaySenSaSun.mid : 5
# GaryMoore-StillGotTheBlues.mid : 5
# GentleRain.mid : 9
# Get_Off_My_Back.mid : 5
# GoodMorningLittleSchoolGirl.mid : 6
# Guerilla_Radio.mid : 6
# HELLO.MID : 3
# Happy_Guy.mid : 6
# Heart_Shaped_Box.mid : 6
# Hey_Bartender.mid : 5
# Higher.mid : 6
# Hobophobic.mid : 6
# Hot pants.mid : 5
# HowIns.mid : 9
# How_Blue_Can_You_Get.mid : 5
# I_NEVER_LOVED_A_MAN__THE_WAY_I_LOVE_YOU.mid : 5
# India.mid : 9
# Iron_Man.mid : 6
# JACKIE_WILSON_BABY_WORKOUT.mid : 5
# JAMES_BROWN_COLD_SWEAT.mid : 5
# JAMES_BROWN_I_GOT_THE_FEELIN_.mid : 5
# JEFFERSON_AIRPLANE__White_Rabbit.mid : 6
# Jazzy_Bossa_Nova_Baby.mid : 9
# JimmieCox-NobodyKnowsWhenYouAreDownAndOut.mid : 5
# JimmieYancey-StateStreetSpecial.mid : 5
# JohnLeeHooker-Dimples.mid : 5
# Juke.mid : 5
# Just Blues.mid : 5
# Keep_It_To_Yourself.mid : 5
# Killing_In_The_Name_Of.mid : 6
# Know_Your_Enemy.mid : 6
# Knowledge.mid : 6
# L2003_01.mid : 9
# L2003_03.mid : 9
# L2003_08.mid : 9
# LA_SALSA.mid : 9
# LITTLE_RICHARD__Slippin_and_Slidin.mid : 5
# LLUVIA.mid : 9
# Last Night The DJ Saved My Life.mid : 5
# LedZeppelin-SinceIveBeenLovingYouBaby.mid : 6
# Little_Red_Rooster.mid : 5
# MASTER_O.MID : 6
# MOJO.mid : 5
# MY_WAVE.MID : 6
# Mable.mid : 6
# Mambo_(Mambo_Mix).mid : 9
# Mamoita.mid : 9
# Mendelssohn-AMidsummer-Overture.mid : 7
# Mendelssohn-ViolinConcerto64-Alegro.mid : 7
# Midnight_Train.mid : 5
# Morena.mid : 9
# Mouvement_1.mid : 7
# MuddyWaters-HoochieCoochieMan.mid : 5
# NOESTAS.mid : 9
# Nitefunk.mid : 3
# No_Particular_Place.mid : 5
# OneBourbonOneScotchOneBeer.mid : 5
# OpFunk.mid : 5
# PRECIOUS.MID : 6
# PUENTE.mid : 9
# Paranoid.mid : 6
# Periodico.mid : 9
# Private_Emotion.mid : 3
# REGGAE.mid : 9
# ROOSTER.MID : 6
# ReggaeisthisLove.mid : 9
# Reggaejammin.mid : 9
# RockMeBaby.mid : 5
# Ruby_Soho.mid : 6
# RufusThomas-WalkingTheDog.mid : 5
# SHOT_GUN.mid : 5
# SMONICA.MID : 6
# Salsa_(Gilberto_SantaRosa)_(Amor_mio_no_te_vayas).mid : 9
# Salsa_(Gilberto_SantaRosa)_(Dime_Cuando).mid : 9
# Salsa_(La_Negra_Tomasa).mid : 9
# Silly_Thing.mid : 6
# Sing_we_and_chant_it.mid : 7
# Smells_Like_Teen_Spirit.mid : 6
# Sodanco.mid : 9
# SonnyBWilliamson-YourFuberalMyTrial.mid : 5
# SonnyBWilliamsonII-UnSeenEye.mid : 5
# SonnyBoyWilliamsonII-DontStartMeToTalking.mid : 5
# Stockhausen_StarSigns.mid : 7
# Suite_1.mid : 7
# Sweet_16.mid : 5
# Sweet_Little_Sixteen.mid : 5
# TBoneWalker-CallItStormyMonday.mid : 5
# TECHNO.mid : 3
# THE_BLUES_BROTHERS_FLIP_FLOP_BLUES.mid : 5
# THE_BLUES_BROTHERS_MINNIE_THE_MOOCHER.mid : 5
# THE_BLUES_BROTHERS_SHAKE_A_TAILFEATHER_BABY.mid : 5
# THE_COMMITMENTS_MIDNIGHT_HOUR.mid : 5
# THE_COMMITMENTS_TRY_A_LITTLE_TENDERNESS.mid : 5
# THE_STAPLE_SINGERS_RESPECT_YOURSELF.mid : 5
# TUMQUEMA.mid : 9
# TangoArg.mid : 9
# The On-Line Boogie.mid : 5
# The_Distance.mid : 6
# The_Thrill_Is_Gone.mid : 5
# Triste.mid : 9
# TuNoLeAmas.mid : 9
# WHEREBOY.MID : 6
# WILSON_PICKET_MEDLEY.mid : 5
# WOULD.MID : 6
# Walk.mid : 6
# Wave3.mid : 9
# Webern_Aufblick.mid : 7
# Whitney_houston_i_will_always_love_you.mid : 3
# YMCA.mid : 3
# a real mother for ya.mid : 5
# ab-astor_tango.mid : 9
# ab-cumparsita_tango.mid : 9
# ab-johnny_b_goode.mid : 5
# ab-tutti_fruitti.mid : 5
# ac_chantons.mid : 7
# aces_high.mid : 6
# against.mid : 3
# ahahohno.mid : 9
# aida1_celeste.mid : 7
# aida2fin.mid : 7
# aleigha.mid : 6
# alive.mid : 6
# allepsaa.mid : 7
# allw_cp3.mid : 7
# amorcomoelnuestro.mid : 9
# angelaonmymind.mid : 3
# angelus.mid : 7
# animal.mid : 6
# another.mid : 3
# another_brick_in_the_wall.mid : 6
# anyplace.mid : 3
# anytime.mid : 3
# aqua-barbie_girl.mid : 3
# around.mid : 5
# around_the_world.mid : 3
# astor_tango.mid : 9
# atIknew.mid : 3
# atthehop.mid : 5
# av002a1.mid : 7
# av_molti2.mid : 7
# b00038.mid : 5
# b00160.mid : 5
# b00178.mid : 6
# b00181.mid : 5
# b00186.mid : 5
# b00188.mid : 6
# b00192.mid : 6
# b00219.mid : 6
# b00245.mid : 6
# b00263.mid : 6
# b00287.mid : 5
# b0028_6.mid : 7
# b00300.mid : 6
# b00317.mid : 6
# b0424.mid : 7
# bach531.mid : 7
# bach7.mid : 7
# bad_love.mid : 6
# barber02_unavoce.mid : 7
# barneys.mid : 5
# bartok_sonata3.mid : 7
# bastien04_befraget.mid : 7
# beet4.mid : 7
# beet5.mid : 7
# beforeac.mid : 5
# belfiore.mid : 7
# berlioz_symfan_5.mid : 7
# billiejn.mid : 3
# birdland.mid : 3
# bjc17_2b.mid : 7
# blazers.mid : 9
# bluemon.mid : 6
# blues_brothers-sweet_home.mid : 5
# bluesy.mid : 5
# bolivar.mid : 5
# boyp.mid : 5
# boys_are_back.mid : 6
# breezin.mid : 3
# britney_spears_oops_i_did_it_again.mid : 3
# britney_spears_stronger.mid : 3
# bux_cfug.mid : 7
# can_t_turn_you_loose.mid : 5
# cant help falling in love.mid : 9
# cap07.mid : 7
# carly_simon_nobody_does_it_better.mid : 3
# cc_rider.mid : 5
# celebrate.mid : 3
# celine_dion_all_by_myself.mid : 3
# chameleon.mid : 5
# chanlace.mid : 5
# chega.mid : 9
# chestnuts.mid : 3
# chicken.mid : 5
# chillout.mid : 3
# chop4.mid : 7
# chop8.mid : 7
# cibux183.mid : 7
# cjam.mid : 5
# clapton-layla.mid : 6
# cm_altri_canti_damor.mid : 7
# cm_combattimento1.mid : 7
# codding_town.mid : 6
# coisalin.mid : 9
# comeback.mid : 3
# comehome.mid : 5
# comerain.mid : 9
# concerto_1_(c)izumi.mid : 7
# concerto_flute_314-2.mid : 7
# control.mid : 3
# copmw.mid : 7
# cosi15_non.mid : 7
# crazy_reg.mid : 9
# cumparsita_tango.mid : 9
# cut the cake.mid : 5
# czaldy.mid : 7
# d-100purelove.mid : 3
# d-123trainwithme.mid : 3
# d-allthatshewants.mid : 9
# d-anothernight.mid : 3
# d-anything.mid : 3
# d-automaticlover.mid : 3
# d-badboy.mid : 3
# d-beautifullife.mid : 3
# d-becauseimlovingyou.mid : 3
# d-bemylover.mid : 3
# d-celebratethelove.mid : 3
# d-children.mid : 3
# d-closetoyou.mid : 3
# d-cocojamboo.mid : 9
# d-cometakemyhand.mid : 3
# d-dancingwithanangel.mid : 3
# dancing.mid : 3
# day_fool.mid : 9
# dc-choochoochaboogie.mid : 5
# deadend.mid : 5
# deb3.mid : 7
# deb5.mid : 7
# december.mid : 6
# dedi.mid : 9
# despavv.mid : 7
# despdpc.mid : 7
# despeie.mid : 7
# despmpl.mid : 7
# dgaria22.mid : 7
# doc-whos_been_talkin.mid : 5
# dock_of_the_bay_2.mid : 5
# dongio04_madamina.mid : 7
# downalley.mid : 5
# dream.mid : 3
# dreams.mid : 6
# ductia.mid : 7
# dufaycas.mid : 7
# dvorak_symphony_9_1l.mid : 7
# dwb-ltsally.mid : 5
# earlyam.mid : 3
# egblues.mid : 5
# elvis_presley_all_shook_up.mid : 5
# eraraute.mid : 7
# eroica-1.mid : 7
# estamp02.mid : 7
# estamp4.mid : 7
# etude.mid : 9
# falando.mid : 9
# felicid.mid : 9
# filthy.mid : 5
# firebird.mid : 7
# fivemil1.mid : 9
# foxbabe.mid : 3
# freedom.mid : 3
# fun3.mid : 5
# funct_u.mid : 5
# g-goyf.mid : 3
# gamespeopleplay.mid : 9
# gboffire.mid : 5
# gbp_serpina.mid : 7
# gel.mid : 6
# gfh_se_bramate_damar.mid : 7
# gfh_va_tacito.mid : 7
# gianni2_omio.mid : 7
# gimme_all_your_lovin.mid : 6
# gimmesh.mid : 6
# go_again.mid : 6
# go_the_distance.mid : 3
# gonions.mid : 5
# greenday_jaded.mid : 6
# gtrblues.mid : 5
# hallfima.mid : 7
# hand3.mid : 7
# hand6.mid : 7
# hangin.mid : 3
# heaven.mid : 6
# heaven_is.mid : 6
# helpme.mid : 5
# hen4sanc.mid : 7
# here i am baby.mid : 9
# heyjoe.mid : 6
# hindemithrag.mid : 7
# hit_the_lights.mid : 6
# holding.mid : 3
# homeinsa.mid : 5
# hootieblues.mid : 5
# house.mid : 6
# how_am_i_supposwithout_you.mid : 3
# hp_amin.mid : 7
# hp_when_i_am.mid : 7
# hysteria.mid : 6
# i'll_never_break_your_heart.mid : 3
# i'm_broken.mid : 6
# icumen.mid : 7
# idv_die_weiber.mid : 7
# in2deep.mid : 3
# irresponsible_hate_anthem.mid : 6
# it's your thing.mid : 5
# it's_all_comingk_to_me_now.mid : 3
# itapoan.mid : 9
# jahlive.mid : 9
# jailhouse.mid : 5
# james_brown-i_feel_good.mid : 5
# james_brown-papas_got.mid : 5
# jbgood_r.mid : 9
# jesus_freak.mid : 6
# jeurobin.mid : 7
# jns_bene.mid : 7
# joy_bossa_nova.mid : 9
# k030.mid : 7
# k058.mid : 7
# kalenda.mid : 7
# kc-band.mid : 3
# kravitz-are_you_gonna_go_my_way.mid : 6
# la_rotta.mid : 7
# lapin.mid : 9
# lazy.mid : 6
# ldsummer.mid : 3
# light_my_fire.mid : 6
# liszt5.mid : 7
# liszt7.mid : 7
# lithium.mid : 6
# lndnchip.mid : 7
# lndnpart.mid : 7
# lndnques.mid : 7
# lohengrin06_fernem.mid : 7
# looking.mid : 3
# lope-isl.mid : 5
# louis_armstrong-all_the_time_in_the_world.mid : 3
# lowdown.mid : 3
# m_people-moving_on_up.mid : 3
# machbont.mid : 7
# machdous.mid : 7
# machmaag.mid : 7
# madunn.mid : 9
# makeit.mid : 3
# maputo.mid : 3
# marley-sherrif.mid : 9
# master_blaster.mid : 9
# may be tomorrow.mid : 9
# meistersinger11_prize.mid : 7
# merulo2.mid : 7
# mistymountainhop.mid : 6
# moanin.mid : 5
# momagot.mid : 5
# mvoyage.mid : 9
# my_destiny.mid : 3
# my_girl.mid : 5
# myfavgame.mid : 6
# naturalmystic.mid : 9
# nevrknow.mid : 9
# nofx-don't_call_me_white.mid : 6
# notgoodenough.mid : 3
# nothingsgonnachangemylove-georgebenson.mid : 3
# nowthat.mid : 3
# nra-she's_driving.mid : 6
# ock4up.mid : 7
# ombra.mid : 9
# omniscur.mid : 7
# onenote.mid : 9
# oppatt.mid : 3
# orpheus.mid : 9
# papillon.mid : 7
# paradise_city.mid : 6
# paul_butterfield-good_morning.mid : 5
# photograph.mid : 6
# piano_concerto_449_1.mid : 7
# piano_sonata_330_1_(c)oguri.mid : 7
# piano_sonata_570_1_(c)oguri.mid : 7
# play that funky music.mid : 5
# plush.mid : 6
# por_una.mid : 9
# ppanther_37.mid : 5
# prokofievSymph52.mid : 7
# propagandhi-anti-manifesto.mid : 6
# ps-lucille.mid : 5
# purple_haze.mid : 6
# quartet_20_6_1_(c)simonetto.mid : 7
# quartet_33_3_2_(c)simonetto.mid : 7
# quartet_33_6_2_(c)simonetto.mid : 7
# r1t.mid : 7
# raylight.mid : 3
# rebel.mid : 5
# redf_glr.mid : 7
# redwine.mid : 9
# reggaecouldyoubeloved.mid : 9
# rememberourgoodtimes.mid : 3
# respect.mid : 5
# revelations.mid : 6
# riders.mid : 6
# rightnow.mid : 6
# roadhouse_blues.mid : 6
# rolloverbeethoven.mid : 5
# romino.mid : 9
# rootcult.mid : 9
# roses_are_red.mid : 3
# runaway.mid : 3
# salsa.mid : 9
# salsa_salsa.mid : 9
# saltare2.mid : 7
# santana-blackmagicwoman.mid : 6
# schlsout.mid : 6
# schoenberg_6stucke2.mid : 7
# school.mid : 5
# schoskk6.mid : 7
# screeching_weasel-dirty_needles.mid : 6
# sexy MF.mid : 5
# shesnot.mid : 6
# shoes.mid : 5
# sinquere.mid : 9
# siunavez.mid : 9
# sjostakovitsj_melancholie.mid : 7
# smoke.mid : 6
# smooth.mid : 6
# somehap.mid : 3
# sonata_17_(c)izumi.mid : 7
# sonata_19_1_(c)iscenko.mid : 7
# sonata_4_2_(c)iscenko.mid : 7
# southern.mid : 6
# spice.mid : 3
# stairway_to_heaven.mid : 6
# start.mid : 6
# suddenly.mid : 3
# sunflower.mid : 3
# surfin.mid : 5
# sweat01.mid : 9
# symphony_088_2_(c)edwards.mid : 7
# symphony_092_1_(c)edwards.mid : 7
# symphony_183_2_(c)ishii.mid : 7
# symphony_35_385_3_(c)cvikl.mid : 7
# symphony_41_551_3_(c)cvikl.mid : 7
# takriver.mid : 5
# tallnom2.mid : 7
# tango_alaluzde.mid : 9
# tango_alousie.mid : 9
# tango_boedo.mid : 9
# tango_celos.mid : 9
# tango_chique.mid : 9
# tango_cumparsa.mid : 9
# tango_elchoclo.mid : 9
# tango_lapunial.mid : 9
# tango_t-uno.mid : 9
# tango_tangoarg.mid : 9
# tangoaa1.mid : 9
# tangoen_wb.mid : 9
# tav_nom.mid : 7
# teddybea.mid : 5
# teen_idols-ketchup_soup.mid : 6
# temple_of_the_bull.mid : 6
# thank you for letting me be mice elf.mid : 5
# the_four_horsemen.mid : 6
# the_shortest_straw.mid : 6
# these_arms_of_mine.mid : 5
# think.mid : 5
# think_twice.mid : 3
# three_times_a_lady.mid : 3
# through_the_never.mid : 6
# tomorrowpeople.mid : 9
# trio66_1.mid : 7
# trouble.mid : 5
# truecols.mid : 3
# turnlove.mid : 3
# u_smile.mid : 3
# unbreak.mid : 3
# van_halen-jump.mid : 6
# vdreq21a.mid : 7
# victomagnum.mid : 7
# victoquartiagnus2.mid : 7
# victpang.mid : 7
# villagepeople_machoman.mid : 3
# vision.mid : 3
# wagn4.mid : 7
# waitinginvain.mid : 9
# waterloo.mid : 3
# watrmeln.mid : 5
# wavem.mid : 9
# wb_ye_sacred_muses.mid : 7
# webern_op28b.mid : 7
# webern_sym1_cmc.mid : 7
# wedding.mid : 6
# whatlove.mid : 3
# where_the_river_flows.mid : 6
# white_room.mid : 6
# whitney_didntwealmosthaveitall.mid : 3
# whosgirl.mid : 3
# whothink.mid : 3
# wmyself2.mid : 6
# wrong-Bartok_all3.mid : 7
# x_ol_lucia.mid : 7
# x_ol_matona_mia_cara.mid : 7
# x_ol_un_jeune_moine.mid : 7
# you_give_love_a_bad_name.mid : 6
# yursong.mid : 3
# zimbabwe.mid : 9
# zz_top-tush.mid : 6

# %%
distinct_genres = []
for x in genres:
    if genres[x] not in distinct_genres:
        distinct_genres.append(genres[x])
print(distinct_genres)
# Out:
# ['5', '6', '7', '3', '9']

# %%
songFeature = []
songGenre = []
for name in songs:
    song = songs[name]
    genre = genres[name]
    
    features = []
    features.append(min(song))
    features.append(max(song))
    features.append(avg(song))
    features.append(common(song))
    
    dist = distance(song)
    
    features.append(min(dist))
    features.append(max(dist))
    features.append(avg(dist))
    features.append(common(dist))
    
    features.extend(histogram(song))
    
    songFeature.append(features)
    songGenre.append(distinct_genres.index(genre))
    
print('Finished!')
# Out:
# Finished!

# %%
sc = StandardScaler()

x = numpy.array(songFeature)
y = numpy.array(songGenre)

# x = sc.fit_transform(x)
# y = to_categorical(y, num_classes=5)

# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)
# print(x_train)
# print(y_train)
print('Finished!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-841175019a65> in <module>
#       4 y = numpy.array(songGenre)
#       5
# ----> 6 x = sc.fit_transform(x)
#       7 y = to_categorical(y, num_classes=5)
#       8
#
# c:\users\hojat\appdata\local\programs\python\python36\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# c:\users\hojat\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# --> 669         return self.partial_fit(X, y)
#     670
#     671     def partial_fit(self, X, y=None):
#
# c:\users\hojat\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     698         X = check_array(X, accept_sparse=('csr', 'csc'),
#     699                         estimator=self, dtype=FLOAT_DTYPES,
# --> 700                         force_all_finite='allow-nan')
#     701
#     702         # Even in the case of `with_mean=False`, we update the mean anyway
#
# c:\users\hojat\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     513                     array = array.astype(dtype, casting="unsafe", copy=False)
#     514                 else:
# --> 515                     array = np.asarray(array, order=order, dtype=dtype)
#     516             except ComplexWarning:
#     517                 raise ValueError("Complex data not supported\n"
#
# c:\users\hojat\appdata\local\programs\python\python36\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: setting an array element with a sequence.

# %%
model = Sequential()
model.add(Dense(70, input_dim=8, activation='relu'))
model.add(Dense(70, activation='relu'))
model.add(Dense(70, activation='relu'))
model.add(Dense(5, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_data = (x_test,y_test), epochs=100)

with open("final-2.2.pickle", "wb") as f:
    pickle.dump(model, f)
# Out:
# Train on 456 samples, validate on 115 samples
# Epoch 1/100
# 456/456 [==============================] - 0s 326us/step - loss: 1.5290 - accuracy: 0.3794 - val_loss: 1.3856 - val_accuracy: 0.5217
# Epoch 2/100
# 456/456 [==============================] - 0s 76us/step - loss: 1.3495 - accuracy: 0.4408 - val_loss: 1.2001 - val_accuracy: 0.5304
# Epoch 3/100
# 456/456 [==============================] - 0s 61us/step - loss: 0.3161 - accuracy: 0.9123 - val_loss: 2.0909 - val_accuracy: 0.5043
# Epoch 87/100
# 456/456 [==============================] - 0s 61us/step - loss: 0.3104 - accuracy: 0.9057 - val_loss: 2.0946 - val_accuracy: 0.5304
# Epoch 88/100
# 456/456 [==============================] - 0s 61us/step - loss: 0.2994 - accuracy: 0.9298 - val_loss: 2.1393 - val_accuracy: 0.5130
# Epoch 89/100
# 456/456 [==============================] - 0s 55us/step - loss: 0.3032 - accuracy: 0.9101 - val_loss: 2.1382 - val_accuracy: 0.5130
# Epoch 90/100
# 456/456 [==============================] - 0s 55us/step - loss: 0.2865 - accuracy: 0.9254 - val_loss: 2.1658 - val_accuracy: 0.5043
# Epoch 91/100
# 456/456 [==============================] - 0s 63us/step - loss: 0.2818 - accuracy: 0.9189 - val_loss: 2.1980 - val_accuracy: 0.4870
# Epoch 92/100
# 456/456 [==============================] - 0s 57us/step - loss: 0.2698 - accuracy: 0.9342 - val_loss: 2.2010 - val_accuracy: 0.5043
# Epoch 93/100
# 456/456 [==============================] - 0s 53us/step - loss: 0.2703 - accuracy: 0.9232 - val_loss: 2.2192 - val_accuracy: 0.4870
# Epoch 94/100
# 456/456 [==============================] - 0s 59us/step - loss: 0.2642 - accuracy: 0.9342 - val_loss: 2.2210 - val_accuracy: 0.5043
# Epoch 95/100
# 456/456 [==============================] - 0s 57us/step - loss: 0.2603 - accuracy: 0.9408 - val_loss: 2.2354 - val_accuracy: 0.5130
# Epoch 96/100
# 456/456 [==============================] - 0s 55us/step - loss: 0.2585 - accuracy: 0.9342 - val_loss: 2.2694 - val_accuracy: 0.5130
# Epoch 97/100
# 456/456 [==============================] - 0s 70us/step - loss: 0.2489 - accuracy: 0.9320 - val_loss: 2.3307 - val_accuracy: 0.5130
# Epoch 98/100
# 456/456 [==============================] - 0s 77us/step - loss: 0.2521 - accuracy: 0.9496 - val_loss: 2.3799 - val_accuracy: 0.5130
# Epoch 99/100
# 456/456 [==============================] - 0s 61us/step - loss: 0.2499 - accuracy: 0.9364 - val_loss: 2.3475 - val_accuracy: 0.5043
# Epoch 100/100
# 456/456 [==============================] - 0s 61us/step - loss: 0.2372 - accuracy: 0.9364 - val_loss: 2.3423 - val_accuracy: 0.5130

# %%
pickle_in = open("final-2.2.pickle", "rb")
model = pickle.load(pickle_in)

# %%
y_pred = model.predict(x_test)
pred = list()
for i in range(len(y_pred)):
    pred.append(np.argmax(y_pred[i]))
test = list()
for i in range(len(y_test)):
    test.append(np.argmax(y_test[i]))

    
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
    

for i in range(len(x_test)):
    y_t = test[i]
    y_p = pred[i]
    
    print("y: " + str(y_t) + " , y_pred: " + str(y_p))
# Out:
# y: 1 , y_pred: 1
# y: 2 , y_pred: 2
# y: 0 , y_pred: 3
# y: 3 , y_pred: 3
# y: 2 , y_pred: 2
# y: 2 , y_pred: 2
# y: 4 , y_pred: 3
# y: 2 , y_pred: 2
# y: 3 , y_pred: 1
# y: 0 , y_pred: 0
# y: 4 , y_pred: 2
# y: 2 , y_pred: 2
# y: 4 , y_pred: 0
# y: 3 , y_pred: 3
# y: 3 , y_pred: 1
# y: 1 , y_pred: 1
# y: 0 , y_pred: 1
# y: 2 , y_pred: 4
# y: 1 , y_pred: 1
# y: 1 , y_pred: 0
# y: 3 , y_pred: 1
# y: 2 , y_pred: 2
# y: 0 , y_pred: 3
# y: 4 , y_pred: 4
# y: 0 , y_pred: 4
# y: 1 , y_pred: 1
# y: 2 , y_pred: 2
# y: 1 , y_pred: 0
# y: 2 , y_pred: 2
# y: 4 , y_pred: 0
# y: 1 , y_pred: 1
# y: 1 , y_pred: 1
# y: 3 , y_pred: 0
# y: 2 , y_pred: 2
# y: 2 , y_pred: 2
# y: 2 , y_pred: 2
# y: 1 , y_pred: 1
# y: 4 , y_pred: 0
# y: 2 , y_pred: 2
# y: 3 , y_pred: 0
# y: 2 , y_pred: 2
# y: 4 , y_pred: 0
# y: 3 , y_pred: 3
# y: 2 , y_pred: 4
# y: 2 , y_pred: 2
# y: 4 , y_pred: 0
# y: 2 , y_pred: 2
# y: 0 , y_pred: 1
# y: 0 , y_pred: 0
# y: 0 , y_pred: 3
# y: 0 , y_pred: 3
# y: 0 , y_pred: 3
# y: 1 , y_pred: 3
# y: 2 , y_pred: 2
# y: 2 , y_pred: 2
# y: 2 , y_pred: 2
# y: 2 , y_pred: 2
# y: 1 , y_pred: 1
# y: 2 , y_pred: 2
# y: 0 , y_pred: 4
# y: 1 , y_pred: 0
# y: 0 , y_pred: 0
# y: 2 , y_pred: 2
# y: 0 , y_pred: 3
# y: 3 , y_pred: 1
# y: 1 , y_pred: 1
# y: 3 , y_pred: 1
# y: 4 , y_pred: 3
# y: 3 , y_pred: 4
# y: 2 , y_pred: 2
# y: 1 , y_pred: 1
# y: 0 , y_pred: 0
# y: 2 , y_pred: 2
# y: 4 , y_pred: 1
# y: 2 , y_pred: 2
# y: 4 , y_pred: 4
# y: 0 , y_pred: 4
# y: 0 , y_pred: 1
# y: 2 , y_pred: 2
# y: 0 , y_pred: 4
# y: 3 , y_pred: 0
# y: 2 , y_pred: 2
# y: 2 , y_pred: 1
# y: 1 , y_pred: 0
# y: 2 , y_pred: 2
# y: 2 , y_pred: 2
# y: 4 , y_pred: 3
# y: 4 , y_pred: 1
# y: 1 , y_pred: 4
# y: 1 , y_pred: 1
# y: 1 , y_pred: 0
# y: 4 , y_pred: 4
# y: 1 , y_pred: 3
# y: 3 , y_pred: 3
# y: 4 , y_pred: 3
# y: 0 , y_pred: 0
# y: 4 , y_pred: 1
# y: 4 , y_pred: 2
# y: 0 , y_pred: 3
# y: 1 , y_pred: 1
# y: 1 , y_pred: 0
# y: 0 , y_pred: 0
# y: 0 , y_pred: 3
# y: 3 , y_pred: 4
# y: 2 , y_pred: 2
# y: 2 , y_pred: 2
# y: 0 , y_pred: 2
# y: 1 , y_pred: 1
# y: 3 , y_pred: 1
# y: 0 , y_pred: 0
# y: 3 , y_pred: 0
# y: 0 , y_pred: 3
# y: 1 , y_pred: 1
# y: 1 , y_pred: 1
# y: 0 , y_pred: 4
